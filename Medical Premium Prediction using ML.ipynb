# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
insurance_df = pd.read_csv(r'C:\Users\divyak3\Downloads\insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#EDA
insurance_df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#Group data by region to find a relationship between region and charges
df_region = insurance_df.groupby(by = 'region').mean()
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %%
#Grouping data by age
df_age = insurance_df.groupby(by='age').mean()
df_age
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# 41   31.506852  1.407407   9653.745650
# 42   30.328148  1.000000  13061.038669
# 43   30.204444  1.629630  19267.278653
# 44   30.844259  1.222222  15859.396587
# 45   29.778966  1.482759  14830.199856
# 46   31.340862  1.620690  14342.590639
# 47   30.664310  1.379310  17653.999593
# 48   31.925690  1.310345  14632.500445
# 49   30.313929  1.500000  12696.006264
# 50   31.132241  1.310345  15663.003301
# 51   31.727069  1.103448  15682.255867
# 52   32.936034  1.482759  18256.269719
# 53   30.360893  1.250000  16020.930755
# 54   31.234286  1.428571  18758.546475
# 55   31.950000  0.961538  16164.545488
# 56   31.600962  0.769231  15025.515837
# 57   30.844423  0.615385  16447.185250
# 58   32.718200  0.240000  13878.928112
# 59   30.572000  1.200000  18895.869532
# 60   30.332826  0.347826  21979.418507
# 61   32.548261  0.739130  22024.457609
# 62   32.342609  0.565217  19163.856573
# 63   31.923478  0.565217  19884.998461
# 64   32.976136  0.772727  23275.530837

# %%
##FEATURE ENGINEERING
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#convert categorical variable to numerical
insurance_df['sex'] = insurance_df['sex'].apply(lambda x: 0    if x=='female' else 1)
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0    if x=='no' else 1)
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)
insurance_df
# Out:
#       age  sex     bmi  children  smoker     region      charges  northwest  \
# 0      19    0  27.900         0       1  southwest  16884.92400          0
# 1      18    1  33.770         1       0  southeast   1725.55230          0
# 2      28    1  33.000         3       0  southeast   4449.46200          0
# 3      33    1  22.705         0       0  northwest  21984.47061          1
# 4      32    1  28.880         0       0  northwest   3866.85520          1
# ...   ...  ...     ...       ...     ...        ...          ...        ...
# 1333   50    1  30.970         3       0  northwest  10600.54830          1
# 1334   18    0  31.920         0       0  northeast   2205.98080          0
# 1335   18    0  36.850         0       0  southeast   1629.83350          0
# 1336   21    0  25.800         0       0  southwest   2007.94500          0
# 1337   61    0  29.070         0       1  northwest  29141.36030          1
#
#       southeast  southwest
# 0             0          1
# 1             1          0
# 2             1          0
# 3             0          0
# 4             0          0
# ...         ...        ...
# 1333          0          0
# 1334          0          0
# 1335          1          0
# 1336          0          1
# 1337          0          0
#
# [1338 rows x 10 columns]

# %%
insurance_df.drop(['region'], axis = 1, inplace= True)
insurance_df
# Out:
#       age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0      19    0  27.900         0       1  16884.92400          0          0
# 1      18    1  33.770         1       0   1725.55230          0          1
# 2      28    1  33.000         3       0   4449.46200          0          1
# 3      33    1  22.705         0       0  21984.47061          1          0
# 4      32    1  28.880         0       0   3866.85520          1          0
# ...   ...  ...     ...       ...     ...          ...        ...        ...
# 1333   50    1  30.970         3       0  10600.54830          1          0
# 1334   18    0  31.920         0       0   2205.98080          0          0
# 1335   18    0  36.850         0       0   1629.83350          0          1
# 1336   21    0  25.800         0       0   2007.94500          0          0
# 1337   61    0  29.070         0       1  29141.36030          1          0
#
#       southwest
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1333          0
# 1334          0
# 1335          0
# 1336          1
# 1337          0
#
# [1338 rows x 9 columns]

# %%
##DATA VISUALIZATION
insurance_df[['age', 'sex', 'bmi', 'children', 'smoker', 'charges']].hist(bins =30, figsize =(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>],
#        [<AxesSubplot:title={'center':'bmi'}>,
#         <AxesSubplot:title={'center':'children'}>],
#        [<AxesSubplot:title={'center':'smoker'}>,
#         <AxesSubplot:title={'center':'charges'}>]], dtype=object)

# %% [markdown]
# #Plot Pairplot
# sns.pairplot(insurance_df)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
#Correlation Matrix
insurance_df.corr()
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex       -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi        0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children   0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker    -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges    0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#            northwest  southeast  southwest
# age        -0.000407  -0.011642   0.010016
# sex        -0.011156   0.017117  -0.004184
# bmi        -0.135996   0.270025  -0.006205
# children    0.024806  -0.023066   0.021914
# smoker     -0.036945   0.068498  -0.036945
# charges    -0.039905   0.073982  -0.043210
# northwest   1.000000  -0.346265  -0.320829
# southeast  -0.346265   1.000000  -0.346265
# southwest  -0.320829  -0.346265   1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(insurance_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns = ['charges'])
Y = insurance_df['charges']
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
Y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
Y = np.array(Y).astype('float32')

# %%
Y = Y.reshape(-1, 1)

# %%
Y
# Out:
# array([[16884.924 ],
#        [ 1725.5522],
#        [ 4449.462 ],
#        ...,
#        [ 1629.8335],
#        [ 2007.945 ],
#        [29141.36  ]], dtype=float32)

# %%
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
Y = scaler_y.fit_transform(Y)

# %%
#Splitting the data for training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 10)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %%
#Using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, accuracy_score

regression_model_sklearn = LinearRegression()
regression_model_sklearn.fit (X_train, Y_train)
# Out:
# LinearRegression()

# %%
regression_model_sklearn_accuracy = regression_model_sklearn.score(X_test, Y_test)
regression_model_sklearn_accuracy
# Out:
# 0.6953286589562266

# %%
Y_predict = regression_model_sklearn.predict(X_test)

# %%
Y_predict_orig = scaler_y.inverse_transform(Y_predict)
Y_test_orig = scaler_y.inverse_transform(Y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(Y_test_orig, Y_predict_orig)), '.3f'))
MSE = mean_squared_error(Y_test_orig, Y_predict_orig)
MAE = mean_absolute_error(Y_test_orig, Y_predict_orig)
r2 = r2_score(Y_test_orig, Y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print ('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =',r2, '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 6536.847
# MSE = 42730370.0
# MAE = 4555.099
# R2 = 0.6953286821755241
# Adjusted R2 = 0.6859179850998647

# %%
conda install tensorflow
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\divyak3\Anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           3 KB
#     abseil-cpp-20211102.0      |       hd77b12b_0         1.7 MB
#     absl-py-1.4.0              |   py39haa95532_0         180 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     blinker-1.6.2              |   py39haa95532_0          29 KB
#     ca-certificates-2023.12.12 |       haa95532_0         127 KB
#     certifi-2023.11.17         |   py39haa95532_0         159 KB
#     curl-7.84.0                |       h2bbff1b_0         142 KB
#     flatbuffers-2.0.0          |       h6c2663c_0         1.4 MB
#     gast-0.5.3                 |     pyhd3eb1b0_0          21 KB
#     google-auth-oauthlib-0.4.4 |     pyhd3eb1b0_0          18 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     keras-2.9.0                |   py39haa95532_0         1.5 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libcurl-7.84.0             |       h86230a5_0         300 KB
#     libprotobuf-3.20.1         |       h23ce68f_0         2.0 MB
#     oauthlib-3.2.2             |   py39haa95532_0         209 KB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     protobuf-3.20.1            |   py39hd77b12b_0         231 KB
#     python-flatbuffers-2.0     |     pyhd3eb1b0_0          34 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     sqlite-3.41.2              |       h2bbff1b_0         894 KB
#     tensorboard-2.9.0          |   py39haa95532_0         5.5 MB
#     tensorboard-data-server-0.6.1|   py39haa95532_0          17 KB
#     tensorboard-plugin-wit-1.8.1|   py39haa95532_0         671 KB
#     tensorflow-2.9.1           |mkl_py39hc9ebea8_1           4 KB
#     tensorflow-base-2.9.1      |mkl_py39h6a7f48e_1        73.3 MB
#     tensorflow-estimator-2.9.0 |   py39haa95532_0         491 KB
#     termcolor-2.1.0            |   py39haa95532_0          12 KB
#     ------------------------------------------------------------
#                                            Total:        89.0 MB
#
# The following NEW packages will be INSTALLED:
#
#
# Note: you may need to restart the kernel to use updated packages.  _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-mkl
#   abseil-cpp         pkgs/main/win-64::abseil-cpp-20211102.0-hd77b12b_0
#   absl-py            pkgs/main/win-64::absl-py-1.4.0-py39haa95532_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   blinker            pkgs/main/win-64::blinker-1.6.2-py39haa95532_0
#   flatbuffers        pkgs/main/win-64::flatbuffers-2.0.0-h6c2663c_0
#   gast               pkgs/main/noarch::gast-0.5.3-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   keras              pkgs/main/win-64::keras-2.9.0-py39haa95532_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   oauthlib           pkgs/main/win-64::oauthlib-3.2.2-py39haa95532_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-2.0-pyhd3eb1b0_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   tensorboard        pkgs/main/win-64::tensorboard-2.9.0-py39haa95532_0
#   tensorboard-data-~ pkgs/main/win-64::tensorboard-data-server-0.6.1-py39haa95532_0
#   tensorboard-plugi~ pkgs/main/win-64::tensorboard-plugin-wit-1.8.1-py39haa95532_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.9.1-mkl_py39hc9ebea8_1
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.9.1-mkl_py39h6a7f48e_1
#   tensorflow-estima~ pkgs/main/win-64::tensorflow-estimator-2.9.0-py39haa95532_0
#   termcolor          pkgs/main/win-64::termcolor-2.1.0-py39haa95532_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.08.22-haa95532_0 --> 2023.12.12-haa95532_0
#   certifi                          2023.7.22-py39haa95532_0 --> 2023.11.17-py39haa95532_0
#   curl                                    7.82.0-h2bbff1b_0 --> 7.84.0-h2bbff1b_0
#   libcurl                                 7.82.0-h86230a5_0 --> 7.84.0-h86230a5_0
#   libprotobuf                             3.19.1-h23ce68f_0 --> 3.20.1-h23ce68f_0
#   protobuf                            3.19.1-py39hd77b12b_0 --> 3.20.1-py39hd77b12b_0
#   sqlite                                  3.38.2-h2bbff1b_0 --> 3.41.2-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# sqlite-3.41.2        | 894 KB    |            |   0%
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
# keras-2.9.0          | 1.5 MB    |            |   0%
#
#
# libcurl-7.84.0       | 300 KB    |            |   0%
#
#
#
# gast-0.5.3           | 21 KB     |            |   0%
#
#
#
#
# google-pasta-0.2.0   | 46 KB     |            |   0%
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    |            |   0%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    |            |   0%
#
#
#
#
#
#
#
# python-flatbuffers-2 | 34 KB     |            |   0%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 127 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# oauthlib-3.2.2       | 209 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 57 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# blinker-1.6.2        | 29 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.9.1     | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-preprocessing- | 35 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 17 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.84.0          | 142 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 159 KB    |            |   0%
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#  ... (more hidden) ...
#
#
#
#
# google-pasta-0.2.0   | 46 KB     | ###4       |  35%
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | 2          |   2%
# sqlite-3.41.2        | 894 KB    | 1          |   2%
#
#
#
#
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
#
#
#
#
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
# sqlite-3.41.2        | 894 KB    | ########   |  81%
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
#
#
#
#
#
#
# python-flatbuffers-2 | 34 KB     | ####6      |  47%
#
#
#
# gast-0.5.3           | 21 KB     | #######4   |  75%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 127 KB    | #2         |  13%
# sqlite-3.41.2        | 894 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# oauthlib-3.2.2       | 209 KB    | 7          |   8%
#
#
# libcurl-7.84.0       | 300 KB    | 5          |   5%
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 57 KB     | ##7        |  28%
#
#
#
#
#
#
#
# python-flatbuffers-2 | 34 KB     | ########## | 100%
#
#
#
#
#
#
#
# python-flatbuffers-2 | 34 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# blinker-1.6.2        | 29 KB     | #####4     |  54%
#
#
#
# gast-0.5.3           | 21 KB     | ########## | 100%
#
#
#
# gast-0.5.3           | 21 KB     | ########## | 100%
#
#
# libcurl-7.84.0       | 300 KB    | ##1        |  21%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 127 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 127 KB    | ########## | 100%
#
#
# libcurl-7.84.0       | 300 KB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 57 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 57 KB     | ########## | 100%
#
#
# libcurl-7.84.0       | 300 KB    | ####2      |  43%
#
# keras-2.9.0          | 1.5 MB    | 1          |   1%
#
# keras-2.9.0          | 1.5 MB    | 2          |   2%
#
#
# libcurl-7.84.0       | 300 KB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.9.1     | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# oauthlib-3.2.2       | 209 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# oauthlib-3.2.2       | 209 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-preprocessing- | 35 KB     | ####5      |  46%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
# blinker-1.6.2        | 29 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# blinker-1.6.2        | 29 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | #####2     |  52%
#
# keras-2.9.0          | 1.5 MB    | 4          |   4%
#
#
# libcurl-7.84.0       | 300 KB    | ########## | 100%
#
#
# libcurl-7.84.0       | 300 KB    | ########## | 100%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.9.1     | 4 KB      | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-preprocessing- | 35 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-preprocessing- | 35 KB     | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    | #          |  10%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 17 KB     | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 159 KB    | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 17 KB     | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 159 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 159 KB    | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
# keras-2.9.0          | 1.5 MB    | ###2       |  33%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    | ########## | 100%
#
#
#
#
#
#
# protobuf-3.20.1      | 231 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
# keras-2.9.0          | 1.5 MB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
# keras-2.9.0          | 1.5 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
# keras-2.9.0          | 1.5 MB    | ######9    |  70%
#
# keras-2.9.0          | 1.5 MB    | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.84.0          | 142 KB    | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.84.0          | 142 KB    | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
#
# keras-2.9.0          | 1.5 MB    | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.84.0          | 142 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.84.0          | 142 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #####6     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.9. | 73.3 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
#Using Artificial Neural Network-Based Regression
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ANN_model = keras.Sequential()
# ANN_model.add(Dense(50, input_dim = 8))
# ANN_model.add(Activation('relu'))
# ANN_model.add(Dense(150))
# ANN_model.add(Activation('relu'))
# ANN_model.add(Dense(150))
# ANN_model.add(Activation('relu'))
# ANN_model.add(Dense(50))
# ANN_model.add(Activation('linear'))
# ANN_model.add(Dense(1))
# ANN_model.compile(loss = 'mse', optimizer = 'adam')
# ANN_model.summary()

# %%
ANN_model.compile(optimizer = 'Adam', loss = 'mean_squared_error')
epochs_hist = ANN_model.fit(X_train, Y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 27ms/step - loss: 0.4188 - val_loss: 0.2201
# Epoch 2/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1862 - val_loss: 0.1961
# Epoch 3/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1561 - val_loss: 0.1988
# Epoch 4/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1381 - val_loss: 0.1701
# Epoch 5/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1331 - val_loss: 0.1687
# Epoch 6/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1317 - val_loss: 0.1757
# Epoch 7/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1234 - val_loss: 0.1712
# Epoch 8/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1240 - val_loss: 0.1801
# Epoch 9/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1162 - val_loss: 0.1728
# Epoch 10/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1172 - val_loss: 0.1886
# Epoch 11/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1155 - val_loss: 0.1818
# Epoch 12/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1087 - val_loss: 0.1941
# Epoch 13/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1070 - val_loss: 0.1895
# Epoch 14/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1109 - val_loss: 0.1860
# Epoch 15/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1031 - val_loss: 0.2011
# Epoch 16/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1068 - val_loss: 0.1956
# Epoch 17/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1027 - val_loss: 0.1921
# Epoch 18/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0969 - val_loss: 0.1924
# Epoch 19/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1021 - val_loss: 0.1945
# Epoch 20/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0989 - val_loss: 0.1949
# Epoch 21/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0914 - val_loss: 0.2154
# Epoch 22/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0909 - val_loss: 0.2031
# Epoch 23/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0918 - val_loss: 0.2026
# Epoch 24/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0909 - val_loss: 0.2244
# Epoch 25/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0926 - val_loss: 0.1931
# Epoch 26/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0828 - val_loss: 0.2099
# Epoch 27/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0821 - val_loss: 0.2184
# Epoch 28/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0836 - val_loss: 0.2125
# Epoch 29/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0847 - val_loss: 0.2131
# Epoch 30/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0807 - val_loss: 0.2120
# Epoch 31/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0765 - val_loss: 0.2197
# Epoch 32/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0798 - val_loss: 0.2403
# Epoch 33/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0788 - val_loss: 0.2031
# Epoch 34/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0742 - val_loss: 0.2336
# Epoch 35/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0741 - val_loss: 0.2152
# Epoch 36/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0702 - val_loss: 0.2318
# Epoch 37/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0645 - val_loss: 0.2245
# Epoch 38/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0688 - val_loss: 0.2326
# Epoch 39/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0656 - val_loss: 0.2357
# Epoch 40/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0621 - val_loss: 0.2283
# Epoch 41/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0651 - val_loss: 0.2321
# Epoch 42/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0602 - val_loss: 0.2235
# Epoch 43/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0588 - val_loss: 0.2388
# Epoch 44/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0649 - val_loss: 0.2197
# Epoch 45/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0631 - val_loss: 0.2312
# Epoch 46/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0616 - val_loss: 0.2382
# Epoch 47/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0531 - val_loss: 0.2289
# Epoch 48/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0590 - val_loss: 0.2157
# Epoch 49/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0561 - val_loss: 0.2336
# Epoch 50/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0581 - val_loss: 0.2270
# Epoch 51/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0552 - val_loss: 0.2567
# Epoch 52/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0489 - val_loss: 0.2342
# Epoch 53/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0499 - val_loss: 0.2630
# Epoch 54/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0581 - val_loss: 0.2388
# Epoch 55/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0507 - val_loss: 0.2475
# Epoch 56/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0435 - val_loss: 0.2348
# Epoch 57/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0478 - val_loss: 0.2389
# Epoch 58/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0442 - val_loss: 0.2672
# Epoch 59/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0503 - val_loss: 0.2383
# Epoch 60/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0509 - val_loss: 0.2432
# Epoch 61/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0432 - val_loss: 0.2358
# Epoch 62/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0431 - val_loss: 0.2463
# Epoch 63/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0421 - val_loss: 0.2550
# Epoch 64/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.2358
# Epoch 65/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.2494
# Epoch 66/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0388 - val_loss: 0.2705
# Epoch 67/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0393 - val_loss: 0.2445
# Epoch 68/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.2643
# Epoch 69/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0361 - val_loss: 0.2540
# Epoch 70/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0347 - val_loss: 0.2672
# Epoch 71/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0364 - val_loss: 0.2764
# Epoch 72/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0387 - val_loss: 0.2517
# Epoch 73/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0425 - val_loss: 0.2743
# Epoch 74/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0419 - val_loss: 0.2779
# Epoch 75/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0603 - val_loss: 0.2430
# Epoch 76/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0373 - val_loss: 0.2589
# Epoch 77/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0365 - val_loss: 0.2499
# Epoch 78/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0407 - val_loss: 0.2440
# Epoch 79/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0353 - val_loss: 0.2719
# Epoch 80/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0332 - val_loss: 0.2498
# Epoch 81/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0343 - val_loss: 0.2544
# Epoch 82/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.2532
# Epoch 83/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.2528
# Epoch 84/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.2543
# Epoch 85/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.2525
# Epoch 86/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.2549
# Epoch 87/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.2636
# Epoch 88/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.2679
# Epoch 89/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.2960
# Epoch 90/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0322 - val_loss: 0.2368
# Epoch 91/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0280 - val_loss: 0.2454
# Epoch 92/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0275 - val_loss: 0.2457
# Epoch 93/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0330 - val_loss: 0.2625
# Epoch 94/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.2718
# Epoch 95/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0343 - val_loss: 0.2536
# Epoch 96/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.2511
# Epoch 97/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0336 - val_loss: 0.2333
# Epoch 98/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0348 - val_loss: 0.2377
# Epoch 99/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0340 - val_loss: 0.2544
# Epoch 100/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.2638

# %%
result = ANN_model.evaluate(X_test, Y_test)
accuracy_ANN = 1-result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2870
# Accuracy : 0.7129655480384827

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
Y_predict = ANN_model.predict(X_test)
plt.plot(Y_test, Y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 3ms/step
# Text(0, 0.5, 'True Values')

# %%
Y_predict_orig = scaler_y.inverse_transform(Y_predict)
Y_test_orig = scaler_y.inverse_transform(Y_test)

# %%
plt.plot(Y_test_orig, Y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(Y_test_orig, Y_predict_orig)), '.3f'))
MSE = mean_squared_error(Y_test_orig, Y_predict_orig)
MAE = mean_absolute_error(Y_test_orig, Y_predict_orig)
r2 = r2_score(Y_test_orig, Y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print ('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =',r2, '\nAdjusted R2 =',adj_r2)
# Out:
# RMSE = 6485.585
# MSE = 42062816.0
# MAE = 3821.9758
# R2 = 0.7000883597597625
# Adjusted R2 = 0.690824679752342
